# %%
python3 main_run_finetune.py --clustered --save_dir ../results_mainfinetune/ --downstream clustering --adata_path ../../data/zgao62/dlpfc_h5ad/151507.h5ad

# %%
python3 main_run_finetune2.py --clustered --save_dir ../results_mainfinetune2/ --downstream clustering --adata_path ../../data/zgao62/dlpfc_h5ad/151507.h5ad
